# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ## 1.Plot the following equation: Logarithmic = θ(log n)

# %%
x = np.arange(50)
y = np.log(7*x)

plt.figure(figsize=(9,5))
plt.plot(x,y)
plt.savefig("1_Logarithmic.png")
plt.show()

# %% [markdown]
# ## 2.Plot the following equation: Linear = θ(n)

# %%
x = np.arange(50)
y = 7*x

plt.figure(figsize=(9,5))
plt.plot(x,y)
plt.savefig("2_Linear.png")
plt.show()

# %% [markdown]
# ## 3.Plot the following equation: Quadratic = θ(n²)

# %%
x = np.arange(50)
y = 7*np.square(x)

plt.figure(figsize=(9,5))
plt.plot(x,y)
plt.savefig("3_Quadratic.png")
plt.show()

# %% [markdown]
# ## 4.Plot the following equation: Cubic = θ(n³)

# %%
x = np.arange(50)
y = 7*np.power(x,3)

plt.figure(figsize=(9,5))
plt.plot(x,y)
plt.savefig("4_Cubic.png")
plt.show()

# %% [markdown]
# ## 5.Plot the following equation: Polynomial = θ(n^4)

# %%
x = np.arange(50)
y = 7*np.power(x,4)

plt.figure(figsize=(9,5))
plt.plot(x,y)
plt.savefig("5_Polynomial.png")
plt.show()
