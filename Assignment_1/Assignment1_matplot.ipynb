# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ## 1.Plot the following equation: Logarithmic = θ(log n)

# %%
x = np.arange(50)
y = 7*np.log(x)

plt.figure(figsize=(9,5))
plt.xlabel('The size of input data') 
plt.ylabel('Time/Space Complexity') 
plt.title("Logarithmic Function")
plt.plot(x,y)
plt.savefig("./EQ_images/1_Logarithmic.jpg")
plt.show()

# %% [markdown]
# ## 2.Plot the following equation: Linear = θ(n)

# %%
x = np.arange(50)
y = 7*x

plt.figure(figsize=(9,5))
plt.xlabel('The size of input data') 
plt.ylabel('Time/Space Complexity') 
plt.title("Linear Function")
plt.plot(x,y)
plt.savefig("./EQ_images/2_Linear.jpg")
plt.show()

# %% [markdown]
# ## 3.Plot the following equation: Quadratic = θ(n²)

# %%
x = np.arange(50)
y = 7*np.square(x)

plt.figure(figsize=(9,5))
plt.xlabel('The size of input data') 
plt.ylabel('Time/Space Complexity') 
plt.title("Quadratic Function")
plt.plot(x,y)
plt.savefig("./EQ_images/3_Quadratic.jpg")
plt.show()

# %% [markdown]
# ## 4.Plot the following equation: Cubic = θ(n³)

# %%
x = np.arange(50)
y = 7*np.power(x,3)

plt.figure(figsize=(9,5))
plt.xlabel('The size of input data') 
plt.ylabel('Time/Space Complexity') 
plt.title("Cubic Function")
plt.plot(x,y)
plt.savefig("./EQ_images/4_Cubic.jpg")
plt.show()

# %% [markdown]
# ## 5.Plot the following equation: Polynomial = θ(n^4)

# %%
x = np.arange(50)
y = 7*np.power(x,4)

plt.figure(figsize=(9,5))
plt.xlabel('The size of input data') 
plt.ylabel('Time/Space Complexity') 
plt.title("Polynomial Function")
plt.plot(x,y)
plt.savefig("./EQ_images/5_Polynomial.jpg")
plt.show()
